# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
# plt.style.use('~/computermodern.mplstyle')

# %%
with open("benchmark_logs/timing_summary.txt", "r") as arquivo:
    conteudo: str = arquivo.read()

# %%
type(conteudo)
# Out:
# str

# %%
extracted_data = re.findall(r"Tempo com (\d+) processo\(s\): (\d+\.\d+)", conteudo)

# %%
data = np.array(extracted_data, dtype=np.float64)
nprocs = data[:,0]
tempos = data[:,1]

# %%
plt.figure(figsize=(7,5))
plt.title("Benchmark Results")
plt.grid(axis='y')
plt.xticks(nprocs)
plt.xlabel("# processors")
plt.ylabel("")
plt.scatter(nprocs, tempos)
plt.scatter(nprocs[1], tempos[1], marker='*', )

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.title("Tempo de Execução em Função do Número de Processadores", fontsize=14)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.xticks(nprocs)
plt.xlabel("Número de Processadores"rue, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.ylabel("Tempo de Execução (s)", fontsize=12)

# Pontos principais
plt.scatter(nprocs, tempos, s=100, label="Execuções Benchmark", color='C0')
# Ponto destacado
plt.scatter(nprocs[1], tempos[1], marker='*', s=200, color='orange', label="Melhor resultado")
plt.legend(fontsize=12, loc='upper left')
plt.tight_layout()
plt.show()
